# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
 
from scipy import stats
# %matplotlib inline
sns.set(style = "darkgrid", font_scale = 1.5)
pd.set_option("display.max.columns", None)
pd.set_option("display.max.rows", None)

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ## Time Series (applicable if time-column (like year, month, etc) exists)
#
# Trends over time for each indicator (global & per country/region).
#
# Life expectancy trends over time by income group.
#
# Immunization coverage change over time.

# %%
df = pd.read_csv("data_life_expectancy_clean.zip")
print(df.sample(5))
# Out:
#        Country  Year      Status  Life expectancy   Adult Mortality  \
# 0  Afghanistan  2015  Developing              65.0            263.0
# 1  Afghanistan  2014  Developing              59.9            271.0
# 2  Afghanistan  2015  Developing              65.0            263.0
# 3  Afghanistan  2014  Developing              59.9            271.0
# 4  Afghanistan  2015  Developing              65.0            263.0
#
#    infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles   \
# 0             62     0.01               71.279624         65.0      1154
# 1             64     0.01               73.523582         62.0       492
# 2             62     0.01               71.279624         65.0      1154
# 3             64     0.01               73.523582         62.0       492
# 4             62     0.01               71.279624         65.0      1154
#
#     BMI   under-five deaths   Polio  Total expenditure  Diphtheria   \
# ...

# %%
# Lets create a df that contains numeric values
numerical_df = df.select_dtypes(include = [np.number])
print(numerical_df.head(5))
# Out:
#    Year  Life Expectancy  Adult Mortality  Infant Deaths  Alcohol  \
# 0  2015             65.0            263.0             62     0.01
# 1  2014             59.9            271.0             64     0.01
# 6  2013             59.9            268.0             66     0.01
# 7  2012             59.5            272.0             69     0.01
# 8  2011             59.2            275.0             71     0.01
#
#    Percentage Expenditure  Hepatitis B  Measles   Bmi  Under-Five Deaths  \
# 0               71.279624         65.0     1154  19.1                 83
# 1               73.523582         62.0      492  18.6                 86
# 6               73.219243         64.0      430  18.1                 89
# 7               78.184215         67.0     2787  17.6                 93
# 8                7.097109         68.0     3013  17.2                 97
#
#    Polio  Total Expenditure  Diphtheria  Hiv/Aids         Gdp  Population  \
# ...

# %%
# Lets create a df that contains categorical values
categorical_df = df.select_dtypes(include = ['object'])
print(categorical_df.head(5))
# Out:
#        Country      Status
# 0  Afghanistan  Developing
# 1  Afghanistan  Developing
# 6  Afghanistan  Developing
# 7  Afghanistan  Developing
# 8  Afghanistan  Developing

# %%
## TO BE CONTINUED.....
