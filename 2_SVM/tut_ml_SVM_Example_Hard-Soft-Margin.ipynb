# %% [markdown]
# # SVM
# Here I use scikit module: svm.
#
# A soft margin allows misclassification by introducing a regularization parameter C:
# - Large C → less tolerance for misclassification (harder margin).
# - Small C → more tolerance for misclassification (softer margin).

# %% [markdown]
# ## Hard margin
# - Here I am using C=1

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.svm import SVC
from sklearn.datasets import make_blobs

# Create a simple 2-class dataset
X, y = make_blobs(n_samples=30, centers=2, random_state=6)

# Fit a linear SVM
model = SVC(kernel='linear', C=1.0)
model.fit(X, y)

# Get weights and bias
w = model.coef_[0]
b = model.intercept_[0]
print(f"w: {w}")
print(f"b: {b}")

# Calculate the margin
margin = 2 / np.linalg.norm(w)

# Plotting
plt.figure(figsize=(8, 6))

# Plot data points
plt.scatter(X[:, 0], X[:, 1], c=y, s=30, cmap=plt.cm.Paired)

# Plot support vectors
plt.scatter(model.support_vectors_[:, 0], model.support_vectors_[:, 1],
            s=100, facecolors='none', edgecolors='k', label='Support Vectors')

# Create a grid to plot the decision boundary and margins
ax = plt.gca()
xlim = ax.get_xlim()
ylim = ax.get_ylim()

xx = np.linspace(xlim[0], xlim[1])
yy = -(w[0] * xx + b) / w[1]  # Decision boundary
yy_margin_up = yy + margin / 2
yy_margin_down = yy - margin / 2

# Plot decision boundary and margins
plt.plot(xx, yy, 'k-')
plt.plot(xx, yy_margin_up, 'k--')
plt.plot(xx, yy_margin_down, 'k--')

plt.title(f'SVM with Margin = {margin:.2f}')
plt.legend()
plt.xlabel('Feature 1')
plt.ylabel('Feature 2')
plt.grid(True)
plt.show()
# Out:
# w: [-0.4635122  -0.69914599]
# b: -1.0154377593826265

# %% [markdown]
# ## Soft margin
# - increase C from 0.01, 0.05, 0.1, 0.2

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.svm import SVC
from sklearn.datasets import make_blobs

# Create a simple 2-class dataset
X, y = make_blobs(n_samples=30, centers=2, random_state=6)

# Fit a linear SVM
model = SVC(kernel='linear', C=0.05) # change C = 0.01, 0.05,0.1,0.5
model.fit(X, y)

# Get weights and bias
w = model.coef_[0]
b = model.intercept_[0]
print(f"w: {w}")
print(f"b: {b}")

# Calculate the margin
margin = 2 / np.linalg.norm(w)

# Plotting
plt.figure(figsize=(8, 6))

# Plot data points
plt.scatter(X[:, 0], X[:, 1], c=y, s=30, cmap=plt.cm.Paired)

# Plot support vectors
plt.scatter(model.support_vectors_[:, 0], model.support_vectors_[:, 1],
            s=100, facecolors='none', edgecolors='k', label='Support Vectors')

# Create a grid to plot the decision boundary and margins
ax = plt.gca()
xlim = ax.get_xlim()
ylim = ax.get_ylim()

xx = np.linspace(xlim[0], xlim[1])
yy = -(w[0] * xx + b) / w[1]  # Decision boundary
yy_margin_up = yy + margin / 2
yy_margin_down = yy - margin / 2

# Plot decision boundary and margins
plt.plot(xx, yy, 'k-')
plt.plot(xx, yy_margin_up, 'k--')
plt.plot(xx, yy_margin_down, 'k--')

plt.title(f'SVM with Margin = {margin:.2f}')
plt.legend()
plt.xlabel('Feature 1')
plt.ylabel('Feature 2')
plt.grid(True)
plt.show()
# Out:
# w: [-0.15499481 -0.47427575]
# b: -1.8060684271730607
