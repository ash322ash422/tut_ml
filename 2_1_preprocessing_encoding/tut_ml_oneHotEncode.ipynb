# %%
import io
import pandas as pd

# 1. The data dictionary matching your DataFrame
data = {
    "Name": ["Alice", "Bob", "Charlie", "David", "Eva"],
    "Age": [25, 30, 35, 40, 22],
    "City": ["Amman", "Houston", "Delhi", "Amman", "Houston"],
    "Experience": [2, 5, 7, 10, 1],
    "Salary": [70000.0, 30.0, 66000.0, 90000.0, 48000.0],
}

# 2. Recreate the DataFrame from the dictionary
df = pd.DataFrame(data)

print(df)
# Out:
#       Name  Age     City  Experience   Salary
# 0    Alice   25    Amman           2  70000.0
# 1      Bob   30  Houston           5     30.0
# 2  Charlie   35    Delhi           7  66000.0
# 3    David   40    Amman          10  90000.0
# 4      Eva   22  Houston           1  48000.0

# %% [markdown]
# ## One-Hot Encoding categorical variables
# Lets say we have 4 variables: A,B,C and D
#
# One hot encoding creates a 4 element vector:
#
# A -> (1,0,0,0)
#
# B -> (0,1,0,0)
#
# C -> (0,0,1,0)
#
# D -> (0,0,0,1)

# %%
# One-Hot Encoding categorical variables

from sklearn.preprocessing import OneHotEncoder

encoder = OneHotEncoder(sparse_output=False, drop='first')

cities_encoded = encoder.fit_transform(df[['City']])
city_columns = encoder.get_feature_names_out(['City'])
df_cities = pd.DataFrame(cities_encoded, columns=city_columns)

df = pd.concat([df, df_cities], axis=1).drop(columns=['City'])
print("\nDataFrame after one-hot encoding City column:\n", df.head())
# Out:
# DataFrame after one-hot encoding City column:
#        Name  Age  Experience   Salary  City_Delhi  City_Houston
# 0    Alice   25           2  70000.0         0.0           0.0
# 1      Bob   30           5     30.0         0.0           1.0
# 2  Charlie   35           7  66000.0         1.0           0.0
# 3    David   40          10  90000.0         0.0           0.0
# 4      Eva   22           1  48000.0         0.0           1.0
