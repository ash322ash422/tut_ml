# %% [markdown]
# ## What is Exploratory Data Analysis?

# %% [markdown]
# **Exploratory Data Analysis** or **(EDA)** is understanding the data sets by summarizing their main characteristics often plotting them visually. This step is very important especially when we arrive at modeling the data in order to apply Data Science. Plotting in EDA consists of Histograms, Box plot, Scatter plot and many more. It often takes much time to explore the data. Through the process of EDA, we can ask to define the problem statement or definition on our data set which is very important.

# %% [markdown]
# ### Tips Dataset:
# The dataset contains information about tips received by waiters in a restaurant. It includes demographic and order-related details for each dining party and how much tip they left.
# ```
# total_bill   ---->  float64 (cost of the meal including tax, excluding tip)
# tip          ---->  float64 (Tip amount given by the customer)
# sex          ---->  category (Gender of the person who paid the bill (Male or Female))
# smoker       ---->  category (Whether the person was a smoker (Yes or No))
# day          ---->  category (Day of the week (Thur, Fri, Sat, Sun))
# time         ---->  category (Time of day (Lunch or Dinner))
# size         ---->  int64 (Number of people in the dining party)
# ```

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
# Out:
# C:\Users\hi\AppData\Local\Temp\ipykernel_20816\2945004344.py:2: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# %% [markdown]
# ## Importing the necessary libraries

# %%
import matplotlib.pyplot as plt
import seaborn as sns

#supress warnings
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Loading the dataset

# %%
# df = sns.load_dataset('tips')
# df.to_csv('data_tips.csv', index=False)

import  pandas as pd
df = pd.read_csv('data_tips.csv')

# %% [markdown]
# ### Fetch first few data from dataset

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# ### Description of the dataset

# %%
df.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %% [markdown]
# Checking the DataType of each column

# %%
df.dtypes
# Out:
# total_bill    float64
# tip           float64
# sex            object
# smoker         object
# day            object
# time           object
# size            int64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    object
#  3   smoker      244 non-null    object
#  4   day         244 non-null    object
#  5   time        244 non-null    object
#  6   size        244 non-null    int64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 13.5+ KB

# %% [markdown]
# Columns in DataFrame

# %%
df.columns
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size'], dtype='object')

# %% [markdown]
# #### Unique Values

# %%
print(df.sex.unique())
print("111111111111111")
print(df.day.unique())
print("222222222222222")
print(df.time.unique())
print("33333333333333333")
print(df.smoker.unique())
# Out:
# ['Female' 'Male']
# 111111111111111
# ['Sun' 'Sat' 'Thur' 'Fri']
# 222222222222222
# ['Dinner' 'Lunch']
# 33333333333333333
# ['No' 'Yes']

# %% [markdown]
# Shape of the DataFrame

# %%
df.shape
# Out:
# (244, 7)

# %% [markdown]
# Checking for Null Values

# %%
df.isnull().sum()
# Out:
# total_bill    0
# tip           0
# sex           0
# smoker        0
# day           0
# time          0
# size          0
# dtype: int64

# %% [markdown]
# Checking the index value of the dataframe using iloc

# %%
df.iloc[2]
# Out:
# total_bill     21.01
# tip              3.5
# sex             Male
# smoker            No
# day              Sun
# time          Dinner
# size               3
# Name: 2, dtype: object

# %%
df.iloc[[2, 4, 6]]
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 4       24.59  3.61  Female     No  Sun  Dinner     4
# 6        8.77  2.00    Male     No  Sun  Dinner     2

# %%
df.iloc[7:12]
# Out:
#     total_bill   tip     sex smoker  day    time  size
# 7        26.88  3.12    Male     No  Sun  Dinner     4
# 8        15.04  1.96    Male     No  Sun  Dinner     2
# 9        14.78  3.23    Male     No  Sun  Dinner     2
# 10       10.27  1.71    Male     No  Sun  Dinner     2
# 11       35.26  5.00  Female     No  Sun  Dinner     4

# %%
#indexing the dataframe using .loc

#selecting the specific rows and column as user input(1-5 rows and 2nd and 4th cols)
df.loc[1:5, ["sex", "smoker"]]
# Out:
#       sex smoker
# 1    Male     No
# 2    Male     No
# 3    Male     No
# 4  Female     No
# 5    Male     No

# %% [markdown]
# Inter - Quantile Range (IQR - For Total Bill

# %%
Q1 = df.total_bill.quantile(0.25)
Q3 = df.total_bill.quantile(0.75)
IQR = Q3 - Q1
print(IQR)
# Out:
# 10.779999999999998

# %% [markdown]
# ## Set DataFrame Visualization

# %% [markdown]
# Set Background Color & Font Color

# %%
df_numeric = df.select_dtypes(include='number')

df_numeric.style.set_properties(**{'background-color': 'black', 
                           'color': 'green'})
# df.style.set_properties(**{'background-color': 'black', 
#                            'color': 'green'})
# Out:
# <style type="text/css">
# #T_c0050_row0_col0, #T_c0050_row0_col1, #T_c0050_row0_col2, #T_c0050_row1_col0, #T_c0050_row1_col1, #T_c0050_row1_col2, #T_c0050_row2_col0, #T_c0050_row2_col1, #T_c0050_row2_col2, #T_c0050_row3_col0, #T_c0050_row3_col1, #T_c0050_row3_col2, #T_c0050_row4_col0, #T_c0050_row4_col1, #T_c0050_row4_col2, #T_c0050_row5_col0, #T_c0050_row5_col1, #T_c0050_row5_col2, #T_c0050_row6_col0, #T_c0050_row6_col1, #T_c0050_row6_col2, #T_c0050_row7_col0, #T_c0050_row7_col1, #T_c0050_row7_col2, #T_c0050_row8_col0, #T_c0050_row8_col1, #T_c0050_row8_col2, #T_c0050_row9_col0, #T_c0050_row9_col1, #T_c0050_row9_col2, #T_c0050_row10_col0, #T_c0050_row10_col1, #T_c0050_row10_col2, #T_c0050_row11_col0, #T_c0050_row11_col1, #T_c0050_row11_col2, #T_c0050_row12_col0, #T_c0050_row12_col1, #T_c0050_row12_col2, #T_c0050_row13_col0, #T_c0050_row13_col1, #T_c0050_row13_col2, #T_c0050_row14_col0, #T_c0050_row14_col1, #T_c0050_row14_col2, #T_c0050_row15_col0, #T_c0050_row15_col1, #T_c0050_row15_col2, #T_c0050_row16_col0, #T_c0050_row16_col1, #T_c0050_row16_col2, #T_c0050_row17_col0, #T_c0050_row17_col1, #T_c0050_row17_col2, #T_c0050_row18_col0, #T_c0050_row18_col1, #T_c0050_row18_col2, #T_c0050_row19_col0, #T_c0050_row19_col1, #T_c0050_row19_col2, #T_c0050_row20_col0, #T_c0050_row20_col1, #T_c0050_row20_col2, #T_c0050_row21_col0, #T_c0050_row21_col1, #T_c0050_row21_col2, #T_c0050_row22_col0, #T_c0050_row22_col1, #T_c0050_row22_col2, #T_c0050_row23_col0, #T_c0050_row23_col1, #T_c0050_row23_col2, #T_c0050_row24_col0, #T_c0050_row24_col1, #T_c0050_row24_col2, #T_c0050_row25_col0, #T_c0050_row25_col1, #T_c0050_row25_col2, #T_c0050_row26_col0, #T_c0050_row26_col1, #T_c0050_row26_col2, #T_c0050_row27_col0, #T_c0050_row27_col1, #T_c0050_row27_col2, #T_c0050_row28_col0, #T_c0050_row28_col1, #T_c0050_row28_col2, #T_c0050_row29_col0, #T_c0050_row29_col1, #T_c0050_row29_col2, #T_c0050_row30_col0, #T_c0050_row30_col1, #T_c0050_row30_col2, #T_c0050_row31_col0, #T_c0050_row31_col1, #T_c0050_row31_col2, #T_c0050_row32_col0, #T_c0050_row32_col1, #T_c0050_row32_col2, #T_c0050_row33_col0, #T_c0050_row33_col1, #T_c0050_row33_col2, #T_c0050_row34_col0, #T_c0050_row34_col1, #T_c0050_row34_col2, #T_c0050_row35_col0, #T_c0050_row35_col1, #T_c0050_row35_col2, #T_c0050_row36_col0, #T_c0050_row36_col1, #T_c0050_row36_col2, #T_c0050_row37_col0, #T_c0050_row37_col1, #T_c0050_row37_col2, #T_c0050_row38_col0, #T_c0050_row38_col1, #T_c0050_row38_col2, #T_c0050_row39_col0, #T_c0050_row39_col1, #T_c0050_row39_col2, #T_c0050_row40_col0, #T_c0050_row40_col1, #T_c0050_row40_col2, #T_c0050_row41_col0, #T_c0050_row41_col1, #T_c0050_row41_col2, #T_c0050_row42_col0, #T_c0050_row42_col1, #T_c0050_row42_col2, #T_c0050_row43_col0, #T_c0050_row43_col1, #T_c0050_row43_col2, #T_c0050_row44_col0, #T_c0050_row44_col1, #T_c0050_row44_col2, #T_c0050_row45_col0, #T_c0050_row45_col1, #T_c0050_row45_col2, #T_c0050_row46_col0, #T_c0050_row46_col1, #T_c0050_row46_col2, #T_c0050_row47_col0, #T_c0050_row47_col1, #T_c0050_row47_col2, #T_c0050_row48_col0, #T_c0050_row48_col1, #T_c0050_row48_col2, #T_c0050_row49_col0, #T_c0050_row49_col1, #T_c0050_row49_col2, #T_c0050_row50_col0, #T_c0050_row50_col1, #T_c0050_row50_col2, #T_c0050_row51_col0, #T_c0050_row51_col1, #T_c0050_row51_col2, #T_c0050_row52_col0, #T_c0050_row52_col1, #T_c0050_row52_col2, #T_c0050_row53_col0, #T_c0050_row53_col1, #T_c0050_row53_col2, #T_c0050_row54_col0, #T_c0050_row54_col1, #T_c0050_row54_col2, #T_c0050_row55_col0, #T_c0050_row55_col1, #T_c0050_row55_col2, #T_c0050_row56_col0, #T_c0050_row56_col1, #T_c0050_row56_col2, #T_c0050_row57_col0, #T_c0050_row57_col1, #T_c0050_row57_col2, #T_c0050_row58_col0, #T_c0050_row58_col1, #T_c0050_row58_col2, #T_c0050_row59_col0, #T_c0050_row59_col1, #T_c0050_row59_col2, #T_c0050_row60_col0, #T_c0050_row60_col1, #T_c0050_row60_col2, #T_c0050_row61_col0, #T_c0050_row61_col1, #T_c0050_row61_col2, #T_c0050_row62_col0, #T_c0050_row62_col1, #T_c0050_row62_col2, #T_c0050_row63_col0, #T_c0050_row63_col1, #T_c0050_row63_col2 ...

# %% [markdown]
# Set background color for min value in column containing numbers

# %%
# df.style.highlight_min(axis=0) # changed

def highlight_min_with_bg(s):
    is_min = s == s.min()
    return ['background-color: darkorange; color: white' if v else 'background-color: black; color: green' for v in is_min]

# Apply to the whole DataFrame
df_numeric.style.apply(highlight_min_with_bg, axis=0)
# Out:
# <style type="text/css">
# #T_83745_row0_col0, #T_83745_row0_col1, #T_83745_row0_col2, #T_83745_row1_col0, #T_83745_row1_col1, #T_83745_row1_col2, #T_83745_row2_col0, #T_83745_row2_col1, #T_83745_row2_col2, #T_83745_row3_col0, #T_83745_row3_col1, #T_83745_row3_col2, #T_83745_row4_col0, #T_83745_row4_col1, #T_83745_row4_col2, #T_83745_row5_col0, #T_83745_row5_col1, #T_83745_row5_col2, #T_83745_row6_col0, #T_83745_row6_col1, #T_83745_row6_col2, #T_83745_row7_col0, #T_83745_row7_col1, #T_83745_row7_col2, #T_83745_row8_col0, #T_83745_row8_col1, #T_83745_row8_col2, #T_83745_row9_col0, #T_83745_row9_col1, #T_83745_row9_col2, #T_83745_row10_col0, #T_83745_row10_col1, #T_83745_row10_col2, #T_83745_row11_col0, #T_83745_row11_col1, #T_83745_row11_col2, #T_83745_row12_col0, #T_83745_row12_col1, #T_83745_row12_col2, #T_83745_row13_col0, #T_83745_row13_col1, #T_83745_row13_col2, #T_83745_row14_col0, #T_83745_row14_col1, #T_83745_row14_col2, #T_83745_row15_col0, #T_83745_
T_83745_row58_col1, #T_83745_row58_col2, #T_83745_row59_col0, #T_83745_row59_col1, #T_83745_row59_col2, #T_83745_row60_col0, #T_83745_row60_col1, #T_83745_row60_col2, #T_83745_row61_col0, #T_83745_row61_col1, #T_83745_row61_col2, #T_83745_row62_col0, #T_83745_row62_col1, #T_83745_row62_col2, #T_83745_row63_col0, #T_83745_row63_col1, #T_83745_row63_col2 ...

# %% [markdown]
# Set background color for max value in column containing numbers

# %%
# Custom function to highlight max values with custom colors
def highlight_max_with_bg(s):
    is_max = s == s.max()
    return ['background-color: darkred; color: white' if v else 'background-color: black; color: green' for v in is_max]

# Apply to the numeric DataFrame
df_numeric.style.apply(highlight_max_with_bg, axis=0)
# Out:
# <style type="text/css">
# #T_9d81b_row0_col0, #T_9d81b_row0_col1, #T_9d81b_row0_col2, #T_9d81b_row1_col0, #T_9d81b_row1_col1, #T_9d81b_row1_col2, #T_9d81b_row2_col0, #T_9d81b_row2_col1, #T_9d81b_row2_col2, #T_9d81b_row3_col0, #T_9d81b_row3_col1, #T_9d81b_row3_col2, #T_9d81b_row4_col0, #T_9d81b_row4_col1, #T_9d81b_row4_col2, #T_9d81b_row5_col0, #T_9d81b_row5_col1, #T_9d81b_row5_col2, #T_9d81b_row6_col0, #T_9d81b_row6_col1, #T_9d81b_row6_col2, #T_9d81b_row7_col0, #T_9d81b_row7_col1, #T_9d81b_row7_col2, #T_9d81b_row8_col0, #T_9d81b_row8_col1, #T_9d81b_row8_col2, #T_9d81b_row9_col0, #T_9d81b_row9_col1, #T_9d81b_row9_col2, #T_9d81b_row10_col0, #T_9d81b_row10_col1, #T_9d81b_row10_col2, #T_9d81b_row11_col0, #T_9d81b_row11_col1, #T_9d81b_row11_col2, #T_9d81b_row12_col0, #T_9d81b_row12_col1, #T_9d81b_row12_col2, #T_9d81b_row13_col0, #T_9d81b_row13_col1, #T_9d81b_row13_col2, #T_9d81b_row14_col0, #T_9d81b_row14_col1, #T_9d81b_row14_col2, #T_9d81b_row15_col0, #T_9d81b_row15_col1, #T_9d81b_row15_col2, #T_9d81b_row16_col0, #T_9d81b_row16_col1, #T_9d81b_row16_col2, #T_9d81b_row17_col0, #T_9d81b_row17_col1, #T_9d81b_row17_col2, #T_9d81b_row18_col0, #T_9d81b_row18_col1, #T_9d81b_row18_col2, #T_9d81b_row19_col0, #T_9d81b_row19_col1, #T_9d81b_row19_col2, #T_9d81b_row20_col0, #T_9d81b_row20_col1, #T_9d81b_row20_col2, #T_9d81b_row21_col0, #T_9d81b_row21_col1, #T_9d81b_row21_col2, #T_9d81b_row22_col0, #T_9d81b_row22_col1, #T_9d81b_row22_col2, #T_9d81b_row23_col0, #T_9d81b_row23_col1, #T_9d81b_row23_col2, #T_9d81b_row24_col0, #T_9d81b_row24_col1, #T_9d81b_row24_col2, #T_9d81b_row25_col0, #T_9d81b_row25_col1, #T_9d81b_row25_col2, #T_9d81b_row26_col0, #T_9d81b_row26_col1, #T_9d81b_row26_col2, #T_9d81b_row27_col0, #T_9d81b_row27_col1, #T_9d81b_row27_col2, #T_9d81b_row28_col0, #T_9d81b_row28_col1, #T_9d81b_row28_col2, #T_9d81b_row29_col0, #T_9d81b_row29_col1, #T_9d81b_row29_col2, #T_9d81b_row30_col0, #T_9d81b_row30_col1, #T_9d81b_row30_col2, #T_9d81b_row31_col0, #T_9d81b_row31_col1, #T_9d81b_row31_col2, #T_9d81b_row32_col0, #T_9d81b_row32_col1, #T_9d81b_row32_col2, #T_9d81b_row33_col0, #T_9d81b_row33_col1, #T_9d81b_row33_col2, #T_9d81b_row34_col0, #T_9d81b_row34_col1, #T_9d81b_row34_col2, #T_9d81b_row35_col0, #T_9d81b_row35_col1, #T_9d81b_row35_col2, #T_9d81b_row36_col0, #T_9d81b_row36_col1, #T_9d81b_row36_col2, #T_9d81b_row37_col0, #T_9d81b_row37_col1, #T_9d81b_row37_col2, #T_9d81b_row38_col0, #T_9d81b_row38_col1, #T_9d81b_row38_col2, #T_9d81b_row39_col0, #T_9d81b_row39_col1, #T_9d81b_row39_col2, #T_9d81b_row40_col0, #T_9d81b_row40_col1, #T_9d81b_row40_col2, #T_9d81b_row41_col0, #T_9d81b_row41_col1, #T_9d81b_row41_col2, #T_9d81b_row42_col0, #T_9d81b_row42_col1, #T_9d81b_row42_col2, #T_9d81b_row43_col0, #T_9d81b_row43_col1, #T_9d81b_row43_col2, #T_9d81b_row44_col0, #T_9d81b_row44_col1, #T_9d81b_row44_col2, #T_9d81b_row45_col0, #T_9d81b_row45_col1, #T_9d81b_row45_col2, #T_9d81b_row46_col0, #T_9d81b_row46_col1, #T_9d81b_row46_col2, #T_9d81b_row47_col0, #T_9d81b_row47_col1, #T_9d81b_row47_col2, #T_9d81b_row48_col0, #T_9d81b_row48_col1, #T_9d81b_row48_col2, #T_9d81b_row49_col0, #T_9d81b_row49_col1, #T_9d81b_row49_col2, #T_9d81b_row50_col0, #T_9d81b_row50_col1, #T_9d81b_row50_col2, #T_9d81b_row51_col0, #T_9d81b_row51_col1, #T_9d81b_row51_col2, #T_9d81b_row52_col0, #T_9d81b_row52_col1, #T_9d81b_row52_col2, #T_9d81b_row53_col0, #T_9d81b_row53_col1, #T_9d81b_row53_col2, #T_9d81b_row54_col0, #T_9d81b_row54_col1, #T_9d81b_row54_col2, #T_9d81b_row55_col0, #T_9d81b_row55_col1, #T_9d81b_row55_col2, #T_9d81b_row56_col0, #T_9d81b_row56_col1, #T_9d81b_row56_col2, #T_9d81b_row57_col0, #T_9d81b_row57_col1, #T_9d81b_row57_col2, #T_9d81b_row58_col0, #T_9d81b_row58_col1, #T_9d81b_row58_col2, #T_9d81b_row59_col0, #T_9d81b_row59_col1, #T_9d81b_row59_col2, #T_9d81b_row60_col0, #T_9d81b_row60_col1, #T_9d81b_row60_col2, #T_9d81b_row61_col0, #T_9d81b_row61_col1, #T_9d81b_row61_col2, #T_9d81b_row62_col0, #T_9d81b_row62_col1, #T_9d81b_row62_col2, #T_9d81b_row63_col0, #T_9d81b_row63_col1, #T_9d81b_row63_col2 ...

# %% [markdown]
# using seaborn library

# %%
cm = sns.light_palette("green", as_cmap=True)
df.style.background_gradient(cmap=cm)
# Out:
# <style type="text/css">
# #T
{
#   background-color: #d1e6d1;
#   color: #000000;
# }
# #T_6d87b_row7_col0, #T_6d87b_row72_col0 {
#   background-color: #76ba76;
#   color: #f1f1f1;
# }
# #T_6d87b_row7_col1, #T_6d87b_row72_col1, #T_6d87b_row109_col0, #T_6d87b_row122_col0, #T_6d87b_row175_col1 {
#   background-color: #b3d8b3;

# %% [markdown]
# ## Data Visualization

# %% [markdown]
# ## Joint Plot:

# %%
sns.jointplot(x="total_bill", y="tip", data=df, size=5)

# %% [markdown]
# ## Scatter Plot:

# %%
#Data
X = df['total_bill']
Y = df['tip']

#scattering the plot
plt.scatter(X, Y)

#define labels for axis
plt.xlabel('Total Bill', fontsize = 15)
plt.ylabel('Tip', fontsize = 15)

#show plot
plt.show()

# %%
import numpy as np
#data
X = df['total_bill']
Y = df['tip']

#scattering the plot
#s is the shape, c is the colour, aplha is for opacity(0 < alpha < 1)
plt.scatter(X, Y, s=np.array(Y)**2, c="green", alpha=0.8)

#title
plt.title('Scatter Plot', fontsize = 18)

#define labels for axis
plt.xlabel('Total Bill', fontsize = 15)
plt.ylabel('Tip', fontsize = 15)

#show plot
plt.show()

# %% [markdown]
# Scatter Plot using random colors

# %%
rng = np.random.RandomState(0)
colors = rng.rand(len(df))
sizes = 1000 * rng.rand(len(df))

plt.figure(figsize = (10, 5))
x = df['total_bill']
y = df['tip']
plt.scatter(x, y, c=colors[:], s=sizes, alpha=0.3,
                   cmap='viridis')
plt.colorbar();

# %% [markdown]
# ## FacetGrid:

# %%
# sns.FacetGrid(tips_data, hue="time", height=5, aspect=1.2) \
#    .map(plt.scatter, "total_bill", "tip") \
#    .add_legend()

g = sns.FacetGrid(df, hue="time", height=5, aspect=1.2)
g.map(plt.scatter, "total_bill", "tip")
g.add_legend()

# %%
sns.FacetGrid(df, hue="time", height=6) \
   .map(sns.kdeplot, "total_bill") \
   .add_legend()

# %% [markdown]
# ## Hist Plot:

# %%
plt.hist(df['total_bill'])
# Out:
# (array([ 7., 42., 68., 51., 31., 19., 12.,  7.,  3.,  4.]),
#  array([ 3.07 ,  7.844, 12.618, 17.392, 22.166, 26.94 , 31.714, 36.488,
#         41.262, 46.036, 50.81 ]),
#  <BarContainer object of 10 artists>)

# %%
x1 = df['total_bill']
x2 = df['tip']
kwargs = dict(histtype='stepfilled', alpha=0.3)

plt.hist(x1, **kwargs)
plt.hist(x2, **kwargs)
# Out:
# (array([41., 79., 66., 27., 19.,  5.,  4.,  1.,  1.,  1.]),
#  array([ 1. ,  1.9,  2.8,  3.7,  4.6,  5.5,  6.4,  7.3,  8.2,  9.1, 10. ]),
#  [<matplotlib.patches.Polygon at 0x24d487c1950>])

# %%
x = df['total_bill']
y = df['tip']

plt.hist2d(x, y, bins=30, cmap='Blues')
cb = plt.colorbar()
cb.set_label('Counts in Hist bin')

# %% [markdown]
# ## Sub Plot:

# %%
x = df['total_bill']
y = df['tip']

fig, ax = plt.subplots()
ax.plot(x, '-b', label='Total Bill')
ax.plot(y, '--r', label='Tip')
ax.axis('equal')
leg = ax.legend();

# %%
fig, ax = plt.subplots()

for key, group in df.groupby('time'):
    group.plot('total_bill', 'tip', yerr='size', label=key, ax=ax)

plt.show()

# %% [markdown]
# ## Bar Plot:

# %%
set(df['smoker'])
# Out:
# {'No', 'Yes'}

# %%
df.smoker.value_counts().plot(kind = 'bar', rot = 0)
plt.show()

# %%
df.smoker.value_counts().plot(kind="bar", rot=0, color="green")

plt.text(x = -0.05, y = df.smoker.value_counts()[1]+1, s = df.smoker.value_counts()[1])
plt.text(x = 0.98, y = df.smoker.value_counts()[0]+2, s = df.smoker.value_counts()[0])

#define the title & labels
plt.title("Bar Plot", fontsize = 18)
plt.xlabel("Smoker", fontsize = 15)
plt.ylabel("Count", fontsize = 15)

plt.show()

# %% [markdown]
# ### Value count of the day in dataset

# %%
df.day.value_counts()
# Out:
# day
# Sat     87
# Sun     76
# Thur    62
# Fri     19
# Name: count, dtype: int64

# %% [markdown]
# ## Pie Chart:

# %%
#'autopct' displays the percentage upto the 1 decimal
#'radiius' sets the radius of pie plot
plt.figure(figsize = (10, 5))
plt.pie(df.day.value_counts(), autopct="%.1f%%", radius=1, labels=['Sat', 'Sun', 'Thur', 'Fri'])

plt.show()

# %%
#eploded pie chart
plt.figure(figsize = (10, 5))
plt.pie(df.day.value_counts(), autopct="%.1f%%", radius=1, labels=['Sat', 'Sun', 'Thur', 'Fri'], explode=[0,0,0,0.4])

plt.show()

# %%
#donut pie plot
plt.pie(df.day.value_counts(), autopct="%.1f%%", radius=1.5, labels=['Sat', 'Sun', 'Thur', 'Fri'])

circle = plt.Circle((0,0), 0.5, color='white')
plot = plt.gcf()
plot.gca().add_artist(circle)

plt.show()

# %% [markdown]
# ## Histogram:

# %%
#plot the histogram

#specify the bins(bar) for histogram
plt.hist(df['tip'], bins=5)

#define labels and title
plt.title("Histogram of Tips Data", fontsize = 18)
plt.xlabel("Tip", fontsize = 15)
plt.ylabel("Frequency",fontsize = 15)

plt.show()

# %% [markdown]
# ## Box Plot:

# %%
# Box Plot -------->

plt.boxplot(df['total_bill'])

#add labels for five number summary
plt.text(x = 1.1, y=df['total_bill'].min(), s='min')
plt.text(x = 1.1, y=df.total_bill.quantile(0.25), s='Q1')
plt.text(x = 1.1, y=df['total_bill'].median(), s='median(Q2)')
plt.text(x = 1.1, y=df.total_bill.quantile(0.75), s='Q3')
plt.text(x = 1.1, y=df['total_bill'].max(), s='max')

#add the graph title and axes labels
plt.title('Boxplot Of Total Bill Amount', fontsize = 18)
plt.ylabel('Total Bill', fontsize = 15)

plt.show()

# %%
plt.boxplot(df['total_bill'])

#add labels for five number summary
plt.text(x = 1.1, y=df['total_bill'].min(), s='min')
plt.text(x = 1.1, y=df.total_bill.quantile(0.25), s='Q1')
plt.text(x = 1.1, y=df['total_bill'].median(), s='median(Q2)')
plt.text(x = 1.1, y=df.total_bill.quantile(0.75), s='Q3')
plt.text(x = 1.1, y=df['total_bill'].max(), s='max')

#add an arrow(annotate) to show the outliers
plt.annotate('Outliers', xy=(0.97, 45), xytext=(0.7, 44), arrowprops=dict(facecolor="black", arrowstyle="simple"))

#add the graph title and axes labels
plt.title('Boxplot Of Total Bill Amount', fontsize = 18)
plt.ylabel('Total Bill', fontsize = 15)

plt.show()

# %% [markdown]
# ## Strip Plot:

# %%
# Strip Plot ------->

sns.stripplot(y = 'tip', x = 'time', data = df)
plt.show()

# %%
#strip plot with jitter to spread the points
sns.stripplot(y = 'tip', x = 'time', data = df, jitter=True)
plt.show()

# %% [markdown]
# ## Swarm Plot:

# %%
#Swarm Plot----------->

sns.swarmplot(y = 'tip', x = 'time', data = df)
plt.show()

# %%
#swarm plot with adding another categorical variable 'day'
sns.swarmplot(y = 'tip', x = 'time', data = df, hue='day')
plt.show()

# %% [markdown]
# ## Violin Plot:

# %%
# Violin Plot ----------->

sns.violinplot(y = 'total_bill', x = 'day', data = df)
plt.show()

# %%
#set the figure size
plt.figure(figsize=(8,5))

#ploting the violin using split-True
sns.violinplot(y = 'total_bill', x = 'day', data = df, hue='sex', split=True)
plt.show()

# %%
#SKIP

# X is a categorical variable. It creates:
# 50 instances of 1
# 100 instances of 2
# 60 instances of 3
# 40 instances of 4
# → Total = 250 values
X =[1]*50+[2]*100+[3]*60+[4]*40

# Y is the numeric variable.
# It generates 250 evenly spaced values between 10 and 90.
Y = np.linspace(10,90,250)


# Z is a categorical variable used for hue.
# It cycles through labels A–F, creating groupings.
# Length = 250 as well, perfectly aligned with X and Y.
Z = (['A']*5+['B']*5+ ['C']*5+['D']*5+ ['E']*5+['F']*5+['A']*5+['B']*5+ ['C']*5+['D']*5)*5

data = pd.DataFrame({'X':X,'Y':Y,'Z':Z})
print(data.head(20))

#set the figure size
plt.figure(figsize=(8,5))

sns.violinplot(y = 'Y',x='X',data=data,hue = 'Z',split= False)

plt.show()
# Out:
#     X          Y  Z
# 0   1  10.000000  A
# 1   1  10.321285  A
# 2   1  10.642570  A
# 3   1  10.963855  A
# 4   1  11.285141  A
# 5   1  11.606426  B
# 6   1  11.927711  B
# 7   1  12.248996  B
# 8   1  12.570281  B
# 9   1  12.891566  B
# 10  1  13.212851  C
# 11  1  13.534137  C
# 12  1  13.855422  C
# 13  1  14.176707  C
# 14  1  14.497992  C
# 15  1  14.819277  D
# 16  1  15.140562  D
# 17  1  15.461847  D
# 18  1  15.783133  D
# 19  1  16.104418  D

# %% [markdown]
# ## Line Plot:

# %%
sns.set(style='darkgrid')
sns.lineplot(x='total_bill', y='tip', data=df)
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.lineplot(x="total_bill", y="tip",
            hue="time", style="time",
            markers=True, dashes=False, data=df)
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %% [markdown]
# ## Pair Plot:

# %%
# Pair Plot----------->

plt.figure(figsize=(8,8))
sns.pairplot(df)
plt.show()

# %%
sns.pairplot(df, vars=["total_bill", "tip"], diag_kind="kde",
             plot_kws = {'alpha': 0.6, 's': 80, 'edgecolor': 'k'})

# %% [markdown]
# ## Distribution Plot:

# %%
# Distribution Plot -------->
sns.distplot(df['total_bill'])
plt.show()

# %%
#iterate the distplot() function over the time

#list the time
time = ['Lunch', 'Dinner']

#iterate through time
for i in time:
    subset = df[df['time']==i]
    
    #Draw the density plot
    sns.distplot(subset['total_bill'],
                 hist=False, #'hist'=False is not plot histogram
                 kde=True, #'kde = True' plots density curve
                kde_kws={'shade':True},
                label=i)

# %% [markdown]
# ## Count Plot:

# %%
# Count Plot ----------->

#set 'time' as a 'hue' parmeter
sns.countplot(data = df, x = 'day', hue = 'time')
plt.show()

# %% [markdown]
# ## Heatmap:

# %%
# Heat Map----------->

#compute correlation
# corr_matrix = tips_data.corr()
# corr_matrix # changed

# Keep only numeric columns
df_numeric = df.select_dtypes(include='number')

corr_matrix = df_numeric.corr()

print(corr_matrix)
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
#annot=True return the correlation values
plt.figure(figsize=(8,6))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm')
plt.title("Correlation Matrix")
plt.show()

# %% [markdown]
# ## Thanks ....
